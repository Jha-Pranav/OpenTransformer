# %%
# install thunder
# !pip install lightning-thunder

# %%
import thunder
import torch


def foo(x, y):
    a = torch.sin(x)
    b = torch.cos(y)
    return a * b


jfoo = thunder.jit(foo)
cfoo = torch.compile(foo)


def compile_bench(dim, device):
    print("dim >>", dim)
    # %timeit foo(torch.randn(dim, dim,device=device), torch.randn(dim, dim,device=device))
    print("with thunder.jit")
    # %timeit jfoo(torch.randn(dim, dim,device=device), torch.randn(dim, dim,device=device))
    print("with torch.compile")
    # %timeit cfoo(torch.randn(dim, dim,device=device), torch.randn(dim, dim,device=device))
    print()

# %%
device = "cuda"
# compile_bench(10,device)
# compile_bench(100,device)
compile_bench(1000, device)
compile_bench(10000, device)
# Out:
# dim >> 1000
# 25.1 µs ± 965 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# with thunder.jit
# 24.9 µs ± 1.69 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# with torch.compile
# 57.8 µs ± 32.3 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)
#
# dim >> 10000
# 11.8 ms ± 3.9 ms per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# with thunder.jit
# 18 ms ± 385 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# with torch.compile
# 52.3 µs ± 29.2 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### Demonstrating Speedups

# %%
import torchvision
from torchvision.models import densenet121

model = densenet121(weights=torchvision.models.densenet.DenseNet121_Weights)

model = model.cuda()
opt_model = torch.compile(model, mode="reduce-overhead")
thun_model = thunder.jit(model)
# Out:
# /home/pranav-pc/.env/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=DenseNet121_Weights.IMAGENET1K_V1`. You can also use `weights=DenseNet121_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# INfrence

# %%
## let's repeat this
for _ in range(5):
    inp = torch.rand(128, 3, 128, 128).cuda()
    # Eager mode
    with torch.no_grad():
        # %time model(inp)

print("~" * 30)

print("Compile mode")

for _ in range(5):
    inp = torch.rand(128, 3, 128, 128).cuda()
    # Compile mode
    with torch.no_grad():
        # %time opt_model(inp)

print("Thunder jit")

for _ in range(5):
    inp = torch.rand(128, 3, 128, 128).cuda()
    # Compile mode
    with torch.no_grad():
        # %time thun_model(inp)   # It is breaking
# Out:
# CPU times: user 263 ms, sys: 27.1 ms, total: 291 ms
# Wall time: 291 ms
# CPU times: user 4.14 ms, sys: 171 µs, total: 4.31 ms
# Wall time: 4.32 ms
# CPU times: user 4.18 ms, sys: 0 ns, total: 4.18 ms
# Wall time: 4.19 ms
# CPU times: user 4.38 ms, sys: 0 ns, total: 4.38 ms
# Wall time: 4.39 ms
# CPU times: user 6.05 ms, sys: 0 ns, total: 6.05 ms
# Wall time: 6.07 ms
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Compile mode
# /home/pranav-pc/.env/lib/python3.11/site-packages/torch/_inductor/compile_fx.py:140: UserWarning: TensorFloat32 tensor cores for float32 matrix multiplication available but not enabled. Consider setting `torch.set_float32_matmul_precision('high')` for better performance.
#   warnings.warn(
# CPU times: user 18.9 s, sys: 5.3 s, total: 24.2 s
# Wall time: 24.7 s
# CPU times: user 368 ms, sys: 55 µs, total: 368 ms
# Wall time: 367 ms
# CPU times: user 223 µs, sys: 224 µs, total: 447 µs
# Wall time: 453 µs
# CPU times: user 207 µs, sys: 208 µs, total: 415 µs
# Wall time: 421 µs
# CPU times: user 396 µs, sys: 0 ns, total: 396 µs
# Wall time: 401 µs
# Thunder jit
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed eval>:1
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.env/lib/python3.11/site-packages/thunder/__init__.py:194, in ThunderModule.forward(self, *args, **kwargs)
#     193 def forward(self, *args, **kwargs):
# --> 194     res = self._forward_fn(*args, **kwargs)
#     195     return res
#
# File ~/.env/lib/python3.11/site-packages/thunder/__init__.py:611, in jit.<locals>.fn_(*args, **kwargs)
#     608 cs.last_trace_host_start = time.time_ns()
#     609 cs.calls += 1
# --> 611 cache_entry, inps, pro_to_epi = get_computation_and_inputs(*args, **kwargs)
#     612 cs.last_trace_host_execution_start = time.time_ns()
#     614 result = cache_entry.computation_fn(*inps)
#
# File ~/.env/lib/python3.11/site-packages/thunder/__init__.py:262, in _with_cache_info_ctx.<locals>.cache_info_wrapper(*args, **kwargs)
#     260 tok = _cache_info_ctx.set({})
#     261 try:
# --> 262     res = fn(*args, **kwargs)
#     263 finally:
#     264     _cache_info_ctx.reset(tok)
#
# File ~/.env/lib/python3.11/site-packages/thunder/__init__.py:498, in jit.<locals>.get_computation_and_inputs(*args, **kwargs)
#     496     prologue_trc: TraceCtx
#     497     computation_trc: TraceCtx
# --> 498     prologue_trc, computation_trc, *maybe_epilogue = interpreter(
#     499         fn, args, kwargs, sharp_edges=cd.sharp_edges
#     500     )
#     502 if maybe_epilogue:
#     503     epilogue_traces = maybe_epilogue
#
# File ~/.env/lib/python3.11/site-packages/thunder/__init__.py:175, in _general_frontend(fn, args, kwargs, sharp_edges)
#     174 def _general_frontend(fn: Callable, args, kwargs, /, *, sharp_edges: SHARP_EDGES_OPTIONS) -> tuple[TraceCtx, TraceCtx]:
# --> 175     return thunder_general_jit(fn, args, kwargs, sharp_edges=sharp_edges)
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/jit_ext.py:1386, in thunder_general_jit(fn, args, kwargs, sharp_edges)
#    1384 with general_jit_ctx(ctx):
#    1385     with tracectx(computation_trace):
# -> 1386         result = jfn(*args, **kwargs)
#    1387         prims.python_return(result)
#    1388         process_recorded_modifications(ctx, epilogue_trace)
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:6580, in interpret.<locals>.fn_(*args, **kwargs)
#    6578     assert isinstance(e, BaseException), e
#    6579     runtimectx.curexc = None
# -> 6580     raise e
#    6582 return interpretation_result
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:6543, in interpret.<locals>.fn_.<locals>.getfn.<locals>.fn_2()
#    6542 def fn_2(args, kwargs):
# -> 6543     return fn(*args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl()
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl()
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torchvision/models/densenet.py:213, in DenseNet.forward()
#     212 def forward(self, x: Tensor) -> Tensor:
# --> 213     features = self.features(x)
#     214     out = F.relu(features, inplace=True)
#     215     out = F.adaptive_avg_pool2d(out, (1, 1))
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl()
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl()
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/container.py:217, in Sequential.forward()
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl()
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl()
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/batchnorm.py:155, in _BatchNorm.forward()
#     152 if self.training and self.track_running_stats:
#     153     # TODO: if statement only here to tell the jit to skip emitting this when it is None
#     154     if self.num_batches_tracked is not None:  # type: ignore[has-type]
# --> 155         self.num_batches_tracked.add_(1)  # type: ignore[has-type]
#     156         if self.momentum is None:  # use cumulative moving average
#     157             exponential_average_factor = 1.0 / float(self.num_batches_tracked)
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:1253, in interpreter_needs_wrap.<locals>.wrapping_wrapper(*args, **kwargs)
#    1250     ukwargs = kwargs
#    1252 try:
# -> 1253     res = ufn(*uargs, **ukwargs)
#    1255     # If result is a WrappedValue, we trust its provenance record
#    1256     if isinstance(res, WrappedValue):
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/proxies.py:1234, in TensorProxy.__getattr__(self, attr)
#    1233 def __getattr__(self, attr: str, /):
# -> 1234     method: None | Callable = resolve_method(attr, self)
#    1235     baseutils.check(method is not None, lambda: f"Unknown attribute {attr}", exception_type=AttributeError)
#    1236     return partial(method, self)
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/langctxs.py:68, in resolve_method(id, *args, **kwargs)
#      66 def resolve_method(id: Any, *args, **kwargs) -> Callable:
#      67     ctx: LanguageContext = get_langctx()
# ---> 68     method: Callable = ctx.get_method(id, *args, **kwargs)
#      69     return method
#
# File ~/.env/lib/python3.11/site-packages/thunder/torch/langctx.py:40, in TorchCtx.get_method(self, id, *args, **kwargs)
#      38     method: None | Callable = _method_name_to_fn_map.get(id, None)
#      39     if method is None:
# ---> 40         raise AttributeError(f"The {self.name} language context has no method {id}")
#      41     return method
#      43 # has_tensor_input is False
#      44 # Defers to the primitive language context when there are no tensor inputs=
#      45 #   (the primitive language context handles operations on numbers)
#
# AttributeError: The torch language context has no method add_
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed eval>:1
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.env/lib/python3.11/site-packages/thunder/__init__.py:194, in ThunderModule.forward(self, *args, **kwargs)
#     193 def forward(self, *args, **kwargs):
# --> 194     res = self._forward_fn(*args, **kwargs)
#     195     return res
#
# File ~/.env/lib/python3.11/site-packages/thunder/__init__.py:611, in jit.<locals>.fn_(*args, **kwargs)
#     608 cs.last_trace_host_start = time.time_ns()
#     609 cs.calls += 1
# --> 611 cache_entry, inps, pro_to_epi = get_computation_and_inputs(*args, **kwargs)
#     612 cs.last_trace_host_execution_start = time.time_ns()
#     614 result = cache_entry.computation_fn(*inps)
#
# File ~/.env/lib/python3.11/site-packages/thunder/__init__.py:262, in _with_cache_info_ctx.<locals>.cache_info_wrapper(*args, **kwargs)
#     260 tok = _cache_info_ctx.set({})
#     261 try:
# --> 262     res = fn(*args, **kwargs)
#     263 finally:
#     264     _cache_info_ctx.reset(tok)
#
# File ~/.env/lib/python3.11/site-packages/thunder/__init__.py:498, in jit.<locals>.get_computation_and_inputs(*args, **kwargs)
#     496     prologue_trc: TraceCtx
#     497     computation_trc: TraceCtx
# --> 498     prologue_trc, computation_trc, *maybe_epilogue = interpreter(
#     499         fn, args, kwargs, sharp_edges=cd.sharp_edges
#     500     )
#     502 if maybe_epilogue:
#     503     epilogue_traces = maybe_epilogue
#
# File ~/.env/lib/python3.11/site-packages/thunder/__init__.py:175, in _general_frontend(fn, args, kwargs, sharp_edges)
#     174 def _general_frontend(fn: Callable, args, kwargs, /, *, sharp_edges: SHARP_EDGES_OPTIONS) -> tuple[TraceCtx, TraceCtx]:
# --> 175     return thunder_general_jit(fn, args, kwargs, sharp_edges=sharp_edges)
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/jit_ext.py:1386, in thunder_general_jit(fn, args, kwargs, sharp_edges)
#    1384 with general_jit_ctx(ctx):
#    1385     with tracectx(computation_trace):
# -> 1386         result = jfn(*args, **kwargs)
#    1387         prims.python_return(result)
#    1388         process_recorded_modifications(ctx, epilogue_trace)
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:6580, in interpret.<locals>.fn_(*args, **kwargs)
#    6578     assert isinstance(e, BaseException), e
#    6579     runtimectx.curexc = None
# -> 6580     raise e
#    6582 return interpretation_result
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:6543, in interpret.<locals>.fn_.<locals>.getfn.<locals>.fn_2()
#    6542 def fn_2(args, kwargs):
# -> 6543     return fn(*args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl()
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl()
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torchvision/models/densenet.py:213, in DenseNet.forward()
#     212 def forward(self, x: Tensor) -> Tensor:
# --> 213     features = self.features(x)
#     214     out = F.relu(features, inplace=True)
#     215     out = F.adaptive_avg_pool2d(out, (1, 1))
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl()
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl()
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/container.py:217, in Sequential.forward()
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl()
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl()
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/batchnorm.py:155, in _BatchNorm.forward()
#     152 if self.training and self.track_running_stats:
#     153     # TODO: if statement only here to tell the jit to skip emitting this when it is None
#     154     if self.num_batches_tracked is not None:  # type: ignore[has-type]
# --> 155         self.num_batches_tracked.add_(1)  # type: ignore[has-type]
#     156         if self.momentum is None:  # use cumulative moving average
#     157             exponential_average_factor = 1.0 / float(self.num_batches_tracked)
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:1253, in interpreter_needs_wrap.<locals>.wrapping_wrapper(*args, **kwargs)
#    1250     ukwargs = kwargs
#    1252 try:
# -> 1253     res = ufn(*uargs, **ukwargs)
#    1255     # If result is a WrappedValue, we trust its provenance record
#    1256     if isinstance(res, WrappedValue):
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/proxies.py:1234, in TensorProxy.__getattr__(self, attr)
#    1233 def __getattr__(self, attr: str, /):
# -> 1234     method: None | Callable = resolve_method(attr, self)
#    1235     baseutils.check(method is not None, lambda: f"Unknown attribute {attr}", exception_type=AttributeError)
#    1236     return partial(method, self)
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/langctxs.py:68, in resolve_method(id, *args, **kwargs)
#      66 def resolve_method(id: Any, *args, **kwargs) -> Callable:
#      67     ctx: LanguageContext = get_langctx()
# ---> 68     method: Callable = ctx.get_method(id, *args, **kwargs)
#      69     return method
#
# File ~/.env/lib/python3.11/site-packages/thunder/torch/langctx.py:40, in TorchCtx.get_method(self, id, *args, **kwargs)
#      38     method: None | Callable = _method_name_to_fn_map.get(id, None)
#      39     if method is None:
# ---> 40         raise AttributeError(f"The {self.name} language context has no method {id}")
#      41     return method
#      43 # has_tensor_input is False
#      44 # Defers to the primitive language context when there are no tensor inputs=
#      45 #   (the primitive language context handles operations on numbers)
#
# AttributeError: The torch language context has no method add_
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed eval>:1
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.env/lib/python3.11/site-packages/thunder/__init__.py:194, in ThunderModule.forward(self, *args, **kwargs)
#     193 def forward(self, *args, **kwargs):
# --> 194     res = self._forward_fn(*args, **kwargs)
#     195     return res
#
# File ~/.env/lib/python3.11/site-packages/thunder/__init__.py:611, in jit.<locals>.fn_(*args, **kwargs)
#     608 cs.last_trace_host_start = time.time_ns()
#     609 cs.calls += 1
# --> 611 cache_entry, inps, pro_to_epi = get_computation_and_inputs(*args, **kwargs)
#     612 cs.last_trace_host_execution_start = time.time_ns()
#     614 result = cache_entry.computation_fn(*inps)
#
# File ~/.env/lib/python3.11/site-packages/thunder/__init__.py:262, in _with_cache_info_ctx.<locals>.cache_info_wrapper(*args, **kwargs)
#     260 tok = _cache_info_ctx.set({})
#     261 try:
# --> 262     res = fn(*args, **kwargs)
#     263 finally:
#     264     _cache_info_ctx.reset(tok)
#
# File ~/.env/lib/python3.11/site-packages/thunder/__init__.py:498, in jit.<locals>.get_computation_and_inputs(*args, **kwargs)
#     496     prologue_trc: TraceCtx
#     497     computation_trc: TraceCtx
# --> 498     prologue_trc, computation_trc, *maybe_epilogue = interpreter(
#     499         fn, args, kwargs, sharp_edges=cd.sharp_edges
#     500     )
#     502 if maybe_epilogue:
#     503     epilogue_traces = maybe_epilogue
#
# File ~/.env/lib/python3.11/site-packages/thunder/__init__.py:175, in _general_frontend(fn, args, kwargs, sharp_edges)
#     174 def _general_frontend(fn: Callable, args, kwargs, /, *, sharp_edges: SHARP_EDGES_OPTIONS) -> tuple[TraceCtx, TraceCtx]:
# --> 175     return thunder_general_jit(fn, args, kwargs, sharp_edges=sharp_edges)
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/jit_ext.py:1386, in thunder_general_jit(fn, args, kwargs, sharp_edges)
#    1384 with general_jit_ctx(ctx):
#    1385     with tracectx(computation_trace):
# -> 1386         result = jfn(*args, **kwargs)
#    1387         prims.python_return(result)
#    1388         process_recorded_modifications(ctx, epilogue_trace)
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:6580, in interpret.<locals>.fn_(*args, **kwargs)
#    6578     assert isinstance(e, BaseException), e
#    6579     runtimectx.curexc = None
# -> 6580     raise e
#    6582 return interpretation_result
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:6543, in interpret.<locals>.fn_.<locals>.getfn.<locals>.fn_2()
#    6542 def fn_2(args, kwargs):
# -> 6543     return fn(*args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl()
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl()
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torchvision/models/densenet.py:213, in DenseNet.forward()
#     212 def forward(self, x: Tensor) -> Tensor:
# --> 213     features = self.features(x)
#     214     out = F.relu(features, inplace=True)
#     215     out = F.adaptive_avg_pool2d(out, (1, 1))
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl()
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl()
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/container.py:217, in Sequential.forward()
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl()
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl()
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/batchnorm.py:155, in _BatchNorm.forward()
#     152 if self.training and self.track_running_stats:
#     153     # TODO: if statement only here to tell the jit to skip emitting this when it is None
#     154     if self.num_batches_tracked is not None:  # type: ignore[has-type]
# --> 155         self.num_batches_tracked.add_(1)  # type: ignore[has-type]
#     156         if self.momentum is None:  # use cumulative moving average
#     157             exponential_average_factor = 1.0 / float(self.num_batches_tracked)
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:1253, in interpreter_needs_wrap.<locals>.wrapping_wrapper(*args, **kwargs)
#    1250     ukwargs = kwargs
#    1252 try:
# -> 1253     res = ufn(*uargs, **ukwargs)
#    1255     # If result is a WrappedValue, we trust its provenance record
#    1256     if isinstance(res, WrappedValue):
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/proxies.py:1234, in TensorProxy.__getattr__(self, attr)
#    1233 def __getattr__(self, attr: str, /):
# -> 1234     method: None | Callable = resolve_method(attr, self)
#    1235     baseutils.check(method is not None, lambda: f"Unknown attribute {attr}", exception_type=AttributeError)
#    1236     return partial(method, self)
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/langctxs.py:68, in resolve_method(id, *args, **kwargs)
#      66 def resolve_method(id: Any, *args, **kwargs) -> Callable:
#      67     ctx: LanguageContext = get_langctx()
# ---> 68     method: Callable = ctx.get_method(id, *args, **kwargs)
#      69     return method
#
# File ~/.env/lib/python3.11/site-packages/thunder/torch/langctx.py:40, in TorchCtx.get_method(self, id, *args, **kwargs)
#      38     method: None | Callable = _method_name_to_fn_map.get(id, None)
#      39     if method is None:
# ---> 40         raise AttributeError(f"The {self.name} language context has no method {id}")
#      41     return method
#      43 # has_tensor_input is False
#      44 # Defers to the primitive language context when there are no tensor inputs=
#      45 #   (the primitive language context handles operations on numbers)
#
# AttributeError: The torch language context has no method add_
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed eval>:1
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.env/lib/python3.11/site-packages/thunder/__init__.py:194, in ThunderModule.forward(self, *args, **kwargs)
#     193 def forward(self, *args, **kwargs):
# --> 194     res = self._forward_fn(*args, **kwargs)
#     195     return res
#
# File ~/.env/lib/python3.11/site-packages/thunder/__init__.py:611, in jit.<locals>.fn_(*args, **kwargs)
#     608 cs.last_trace_host_start = time.time_ns()
#     609 cs.calls += 1
# --> 611 cache_entry, inps, pro_to_epi = get_computation_and_inputs(*args, **kwargs)
#     612 cs.last_trace_host_execution_start = time.time_ns()
#     614 result = cache_entry.computation_fn(*inps)
#
# File ~/.env/lib/python3.11/site-packages/thunder/__init__.py:262, in _with_cache_info_ctx.<locals>.cache_info_wrapper(*args, **kwargs)
#     260 tok = _cache_info_ctx.set({})
#     261 try:
# --> 262     res = fn(*args, **kwargs)
#     263 finally:
#     264     _cache_info_ctx.reset(tok)
#
# File ~/.env/lib/python3.11/site-packages/thunder/__init__.py:498, in jit.<locals>.get_computation_and_inputs(*args, **kwargs)
#     496     prologue_trc: TraceCtx
#     497     computation_trc: TraceCtx
# --> 498     prologue_trc, computation_trc, *maybe_epilogue = interpreter(
#     499         fn, args, kwargs, sharp_edges=cd.sharp_edges
#     500     )
#     502 if maybe_epilogue:
#     503     epilogue_traces = maybe_epilogue
#
# File ~/.env/lib/python3.11/site-packages/thunder/__init__.py:175, in _general_frontend(fn, args, kwargs, sharp_edges)
#     174 def _general_frontend(fn: Callable, args, kwargs, /, *, sharp_edges: SHARP_EDGES_OPTIONS) -> tuple[TraceCtx, TraceCtx]:
# --> 175     return thunder_general_jit(fn, args, kwargs, sharp_edges=sharp_edges)
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/jit_ext.py:1386, in thunder_general_jit(fn, args, kwargs, sharp_edges)
#    1384 with general_jit_ctx(ctx):
#    1385     with tracectx(computation_trace):
# -> 1386         result = jfn(*args, **kwargs)
#    1387         prims.python_return(result)
#    1388         process_recorded_modifications(ctx, epilogue_trace)
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:6580, in interpret.<locals>.fn_(*args, **kwargs)
#    6578     assert isinstance(e, BaseException), e
#    6579     runtimectx.curexc = None
# -> 6580     raise e
#    6582 return interpretation_result
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:6543, in interpret.<locals>.fn_.<locals>.getfn.<locals>.fn_2()
#    6542 def fn_2(args, kwargs):
# -> 6543     return fn(*args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl()
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl()
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torchvision/models/densenet.py:213, in DenseNet.forward()
#     212 def forward(self, x: Tensor) -> Tensor:
# --> 213     features = self.features(x)
#     214     out = F.relu(features, inplace=True)
#     215     out = F.adaptive_avg_pool2d(out, (1, 1))
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl()
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl()
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/container.py:217, in Sequential.forward()
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl()
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl()
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/batchnorm.py:155, in _BatchNorm.forward()
#     152 if self.training and self.track_running_stats:
#     153     # TODO: if statement only here to tell the jit to skip emitting this when it is None
#     154     if self.num_batches_tracked is not None:  # type: ignore[has-type]
# --> 155         self.num_batches_tracked.add_(1)  # type: ignore[has-type]
#     156         if self.momentum is None:  # use cumulative moving average
#     157             exponential_average_factor = 1.0 / float(self.num_batches_tracked)
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:1253, in interpreter_needs_wrap.<locals>.wrapping_wrapper(*args, **kwargs)
#    1250     ukwargs = kwargs
#    1252 try:
# -> 1253     res = ufn(*uargs, **ukwargs)
#    1255     # If result is a WrappedValue, we trust its provenance record
#    1256     if isinstance(res, WrappedValue):
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/proxies.py:1234, in TensorProxy.__getattr__(self, attr)
#    1233 def __getattr__(self, attr: str, /):
# -> 1234     method: None | Callable = resolve_method(attr, self)
#    1235     baseutils.check(method is not None, lambda: f"Unknown attribute {attr}", exception_type=AttributeError)
#    1236     return partial(method, self)
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/langctxs.py:68, in resolve_method(id, *args, **kwargs)
#      66 def resolve_method(id: Any, *args, **kwargs) -> Callable:
#      67     ctx: LanguageContext = get_langctx()
# ---> 68     method: Callable = ctx.get_method(id, *args, **kwargs)
#      69     return method
#
# File ~/.env/lib/python3.11/site-packages/thunder/torch/langctx.py:40, in TorchCtx.get_method(self, id, *args, **kwargs)
#      38     method: None | Callable = _method_name_to_fn_map.get(id, None)
#      39     if method is None:
# ---> 40         raise AttributeError(f"The {self.name} language context has no method {id}")
#      41     return method
#      43 # has_tensor_input is False
#      44 # Defers to the primitive language context when there are no tensor inputs=
#      45 #   (the primitive language context handles operations on numbers)
#
# AttributeError: The torch language context has no method add_
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed eval>:1
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.env/lib/python3.11/site-packages/thunder/__init__.py:194, in ThunderModule.forward(self, *args, **kwargs)
#     193 def forward(self, *args, **kwargs):
# --> 194     res = self._forward_fn(*args, **kwargs)
#     195     return res
#
# File ~/.env/lib/python3.11/site-packages/thunder/__init__.py:611, in jit.<locals>.fn_(*args, **kwargs)
#     608 cs.last_trace_host_start = time.time_ns()
#     609 cs.calls += 1
# --> 611 cache_entry, inps, pro_to_epi = get_computation_and_inputs(*args, **kwargs)
#     612 cs.last_trace_host_execution_start = time.time_ns()
#     614 result = cache_entry.computation_fn(*inps)
#
# File ~/.env/lib/python3.11/site-packages/thunder/__init__.py:262, in _with_cache_info_ctx.<locals>.cache_info_wrapper(*args, **kwargs)
#     260 tok = _cache_info_ctx.set({})
#     261 try:
# --> 262     res = fn(*args, **kwargs)
#     263 finally:
#     264     _cache_info_ctx.reset(tok)
#
# File ~/.env/lib/python3.11/site-packages/thunder/__init__.py:498, in jit.<locals>.get_computation_and_inputs(*args, **kwargs)
#     496     prologue_trc: TraceCtx
#     497     computation_trc: TraceCtx
# --> 498     prologue_trc, computation_trc, *maybe_epilogue = interpreter(
#     499         fn, args, kwargs, sharp_edges=cd.sharp_edges
#     500     )
#     502 if maybe_epilogue:
#     503     epilogue_traces = maybe_epilogue
#
# File ~/.env/lib/python3.11/site-packages/thunder/__init__.py:175, in _general_frontend(fn, args, kwargs, sharp_edges)
#     174 def _general_frontend(fn: Callable, args, kwargs, /, *, sharp_edges: SHARP_EDGES_OPTIONS) -> tuple[TraceCtx, TraceCtx]:
# --> 175     return thunder_general_jit(fn, args, kwargs, sharp_edges=sharp_edges)
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/jit_ext.py:1386, in thunder_general_jit(fn, args, kwargs, sharp_edges)
#    1384 with general_jit_ctx(ctx):
#    1385     with tracectx(computation_trace):
# -> 1386         result = jfn(*args, **kwargs)
#    1387         prims.python_return(result)
#    1388         process_recorded_modifications(ctx, epilogue_trace)
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:6580, in interpret.<locals>.fn_(*args, **kwargs)
#    6578     assert isinstance(e, BaseException), e
#    6579     runtimectx.curexc = None
# -> 6580     raise e
#    6582 return interpretation_result
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:6543, in interpret.<locals>.fn_.<locals>.getfn.<locals>.fn_2()
#    6542 def fn_2(args, kwargs):
# -> 6543     return fn(*args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl()
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl()
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torchvision/models/densenet.py:213, in DenseNet.forward()
#     212 def forward(self, x: Tensor) -> Tensor:
# --> 213     features = self.features(x)
#     214     out = F.relu(features, inplace=True)
#     215     out = F.adaptive_avg_pool2d(out, (1, 1))
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl()
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl()
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/container.py:217, in Sequential.forward()
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl()
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl()
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/torch/nn/modules/batchnorm.py:155, in _BatchNorm.forward()
#     152 if self.training and self.track_running_stats:
#     153     # TODO: if statement only here to tell the jit to skip emitting this when it is None
#     154     if self.num_batches_tracked is not None:  # type: ignore[has-type]
# --> 155         self.num_batches_tracked.add_(1)  # type: ignore[has-type]
#     156         if self.momentum is None:  # use cumulative moving average
#     157             exponential_average_factor = 1.0 / float(self.num_batches_tracked)
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:5942, in _call_dispatch.<locals>._impl()
#    5941 def _impl(fn, *args, **kwargs):
# -> 5942     return fn.__func__(fn.__self__, *args, **kwargs)
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/interpreter.py:1253, in interpreter_needs_wrap.<locals>.wrapping_wrapper(*args, **kwargs)
#    1250     ukwargs = kwargs
#    1252 try:
# -> 1253     res = ufn(*uargs, **ukwargs)
#    1255     # If result is a WrappedValue, we trust its provenance record
#    1256     if isinstance(res, WrappedValue):
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/proxies.py:1234, in TensorProxy.__getattr__(self, attr)
#    1233 def __getattr__(self, attr: str, /):
# -> 1234     method: None | Callable = resolve_method(attr, self)
#    1235     baseutils.check(method is not None, lambda: f"Unknown attribute {attr}", exception_type=AttributeError)
#    1236     return partial(method, self)
#
# File ~/.env/lib/python3.11/site-packages/thunder/core/langctxs.py:68, in resolve_method(id, *args, **kwargs)
#      66 def resolve_method(id: Any, *args, **kwargs) -> Callable:
#      67     ctx: LanguageContext = get_langctx()
# ---> 68     method: Callable = ctx.get_method(id, *args, **kwargs)
#      69     return method
#
# File ~/.env/lib/python3.11/site-packages/thunder/torch/langctx.py:40, in TorchCtx.get_method(self, id, *args, **kwargs)
#      38     method: None | Callable = _method_name_to_fn_map.get(id, None)
#      39     if method is None:
# ---> 40         raise AttributeError(f"The {self.name} language context has no method {id}")
#      41     return method
#      43 # has_tensor_input is False
#      44 # Defers to the primitive language context when there are no tensor inputs=
#      45 #   (the primitive language context handles operations on numbers)
#
# AttributeError: The torch language context has no method add_

# %%
# error : AttributeError: The torch language context has no method add_

# NOT IN A MOOD TO DEBUG AND FIX IT

# %%
# Thunder is in its early stages and should not be used for production runs yet.

# However, it can already deliver outstanding performance for pretraining and finetuning LLMs supported by LitGPT,

# Thunder is written entirely in Python. Even its trace is represented as valid Python at all stages of transformation. This allows unprecedented levels of introspection and extensibility.

# %%
import os

os.environ["TRANSFORMERS_CACHE"] = "/home/pranav-pc/projects/OpenTransformer/checkpoints"
model_name = "mistralai/Mistral-7B-Instruct-v0.2"
from transformers import AutoModel, AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name)
# Out:
# /home/pranav-pc/.env/lib/python3.11/site-packages/transformers/utils/hub.py:124: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(
# Downloading shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
